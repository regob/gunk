# %% [markdown]
# Set up ggplot figure for jupyter

# %%
library(ggplot2)
options(
    repr.plot.width = 14, repr.plot.height = 7, repr.plot.res = 400,
    repr.plot.pointsize = 30,
)

# %%
ggplot(data=iris, aes(x=Petal.Width))+
  geom_histogram(binwidth=0.2, color="black", aes(fill=Species))
# Out:
# plot without title
